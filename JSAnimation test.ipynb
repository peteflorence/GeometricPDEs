# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation
import numpy as np

# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [])
x2line = np.linspace(0,10,1000)
y2line = x2line
ax.plot(x2line, y2line)

x = np.linspace(0, 10, 1000)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=200, interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgIZJRITMLUHXLXDNR">
#     <br>
#     <input id="_anim_sliderIZJRITMLUHXLXDNR" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animIZJRITMLUHXLXDNR.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animIZJRITMLUHXLXDNR.slower()">&#8211;</button>
#     <button onclick="animIZJRITMLUHXLXDNR.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIZJRITMLUHXLXDNR.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectIZJRITMLUHXLXDNR" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgIZJRITMLUHXLXDNR";
#     var slider_id = "_anim_sliderIZJRITMLUHXLXDNR";
#     var loop_select_id = "_anim_loop_selectIZJRITMLUHXLXDNR";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
import math

def plotPlane(theta_deg): 
    def plotObs(theta,ax):
        # Plot circle obstacle 2
        an = linspace(0,2*pi,100)
        r_circ = math.sqrt(5**2 + 12**2)
        print r_circ
        theta_0_circ = math.atan(-5.0/10.0)
        theta_rel_circ = theta + theta_0_circ
        print theta_rel_circ
        line1 = 1*cos(an)+r_circ*math.sin(math.pi + theta_rel_circ), 1*sin(an) - r_circ*math.cos(math.pi + theta_rel_circ)

        # Plot circle obstacle 2
        an = linspace(0,2*pi,100)
        r_circ = math.sqrt(3**2 + 10**2)
        print r_circ
        theta_0_circ = math.atan(3.0/10.0)
        theta_rel_circ = theta + theta_0_circ
        print theta_rel_circ
        line2 = 1*cos(an)+r_circ*math.sin(math.pi + theta_rel_circ), 1*sin(an) - r_circ*math.cos(math.pi + theta_rel_circ)



    # Rotate for theta, measured as 0 true north
    theta = theta_deg*math.pi/180
    plotObs(theta,ax)

    def plotFOV(ax):
        FOVangle = 130*math.pi/180
        FOVlength = 10

        theta_neg = -FOVangle/2
        theta_pos = FOVangle/2

        ax.plot((0,FOVlength*math.cos(math.pi/2-theta_pos)),(0,FOVlength*math.sin(math.pi/2-theta_pos)),color='blue')
        ax.plot((0,FOVlength*math.cos(math.pi/2-theta_neg)),(0,FOVlength*math.sin(math.pi/2-theta_neg)),color='blue')



    ax.axis([-15, 15, -5, 20])

    im = plt.imread('tetrazeph.jpg')
    newax = fig.add_axes([0.477, 0.16, 0.07, 0.1], anchor='SW')
    newax.imshow(im)
    newax.axis('off')

    ax.set_aspect('equal', 'datalim')

    plotFOV(ax)

    return fig

fig, ax = plt.subplots()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [])


def init2():
    fig = plotPlane(0)
    return fig

def animate2(i):
    fig = plotPlane(i)
    return fig



animation.FuncAnimation(fig, animate, init_func=init,
                        frames=50, interval=1, blit=True)
# Out:
# 13.0
# -0.463647609001
# 10.4403065089
# 0.291456794478
# 13.0
# -0.463647609001
# 10.4403065089
# 0.291456794478
# 13.0
# -0.446194316481
# 10.4403065089
# 0.308910086998
# 13.0
# -0.428741023961
# 10.4403065089
# 0.326363379518
# 13.0
# -0.411287731441
# 10.4403065089
# 0.343816672038
# 13.0
# -0.393834438921
# 10.4403065089
# 0.361269964558
# 13.0
# -0.376381146401
# 10.4403065089
# 0.378723257078
# 13.0
# -0.358927853881
# 10.4403065089
# 0.396176549598
# 13.0
# -0.341474561361
# 10.4403065089
# 0.413629842117
# 13.0
# -0.324021268841
# 10.4403065089
# 0.431083134637
# 13.0
# -0.306567976321
# 10.4403065089
# 0.448536427157
# 13.0
# -0.289114683801
# 10.4403065089
# 0.465989719677
# 13.0
# -0.271661391281
# 10.4403065089
# 0.483443012197
# 13.0
# -0.254208098761
# 10.4403065089
# 0.500896304717
# 13.0
# -0.236754806242
# 10.4403065089
# 0.518349597237
# 13.0
# -0.219301513722
# 10.4403065089
# 0.535802889757
# 13.0
# -0.201848221202
# 10.4403065089
# 0.553256182277
# 13.0
# -0.184394928682
# 10.4403065089
# 0.570709474797
# 13.0
# -0.166941636162
# 10.4403065089
# 0.588162767317
# 13.0
# -0.149488343642
# 10.4403065089
# 0.605616059837
# 13.0
# -0.132035051122
# 10.4403065089
# 0.623069352357
# 13.0
# -0.114581758602
# 10.4403065089
# 0.640522644877
# 13.0
# -0.097128466082
# 10.4403065089
# 0.657975937397
# 13.0
# -0.0796751735621
# 10.4403065089
# 0.675429229917
# 13.0
# -0.0622218810421
# 10.4403065089
# 0.692882522437
# 13.0
# -0.0447685885222
# 10.4403065089
# 0.710335814957
# 13.0
# -0.0273152960022
# 10.4403065089
# 0.727789107476
# 13.0
# -0.00986200348228
# 10.4403065089
# 0.745242399996
# 13.0
# 0.00759128903766
# 10.4403065089
# 0.762695692516
# 13.0
# 0.0250445815576
# 10.4403065089
# 0.780148985036
# 13.0
# 0.0424978740775
# 10.4403065089
# 0.797602277556
# 13.0
# 0.0599511665975
# 10.4403065089
# 0.815055570076
# 13.0
# 0.0774044591174
# 10.4403065089
# 0.832508862596
# 13.0
# 0.0948577516374
# 10.4403065089
# 0.849962155116
# 13.0
# 0.112311044157
# 10.4403065089
# 0.867415447636
# 13.0
# 0.129764336677
# 10.4403065089
# 0.884868740156
# 13.0
# 0.147217629197
# 10.4403065089
# 0.902322032676
# 13.0
# 0.164670921717
# 10.4403065089
# 0.919775325196
# 13.0
# 0.182124214237
# 10.4403065089
# 0.937228617716
# 13.0
# 0.199577506757
# 10.4403065089
# 0.954681910236
# 13.0
# 0.217030799277
# 10.4403065089
# 0.972135202756
# 13.0
# 0.234484091797
# 10.4403065089
# 0.989588495276
# 13.0
# 0.251937384317
# 10.4403065089
# 1.0070417878
# 13.0
# 0.269390676837
# 10.4403065089
# 1.02449508032
# 13.0
# 0.286843969357
# 10.4403065089
# 1.04194837284
# 13.0
# 0.304297261877
# 10.4403065089
# 1.05940166536
# 13.0
# 0.321750554397
# 10.4403065089
# 1.07685495788
# 13.0
# 0.339203846917
# 10.4403065089
# 1.0943082504
# 13.0
# 0.356657139437
# 10.4403065089
# 1.11176154292
# 13.0
# 0.374110431956
# 10.4403065089
# 1.12921483544
# 13.0
# 0.391563724476
# 10.4403065089
# 1.14666812796
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgOUJTALAXDXWZMBWH">
#     <br>
#     <input id="_anim_sliderOUJTALAXDXWZMBWH" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animOUJTALAXDXWZMBWH.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animOUJTALAXDXWZMBWH.slower()">&#8211;</button>
#     <button onclick="animOUJTALAXDXWZMBWH.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animOUJTALAXDXWZMBWH.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectOUJTALAXDXWZMBWH" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgOUJTALAXDXWZMBWH";
#     var slider_id = "_anim_sliderOUJTALAXDXWZMBWH";
#     var loop_select_id = "_anim_loop_selectOUJTALAXDXWZMBWH";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animOUJTALAXDXWZMBWH = new Animation(frames, img_id, slider_id, 1, loop_select_id);
#     }, 0);
#   })()
# </script>
